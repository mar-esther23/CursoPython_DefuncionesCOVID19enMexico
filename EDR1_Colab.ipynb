# %% [markdown]
# # Introducción al Análisis de Datos con Python

# %% [markdown]
# # 1. Colab: uso, archivos y bibliotecas
#
# Bienvenido al curso de Introducción al Análisis de Datos con Python.
#
# Durante el curso, aprenderás a manipular y visualizar datos de manera eficiente, utilizando herramientas y técnicas avanzadas. Al final del curso, esperamos que tengas las habilidades necesarias para realizar análisis de datos con confianza y en profundidad. Aunque no se requiere experiencia previa en programación o análisis de datos, se recomienda tener un conocimiento básico de Excel para aprovechar al máximo el curso.
#
# Este tutorial está diseñado para proporcionar una introducción práctica a [Google Colab](https://colab.research.google.com/), el entorno de programación que usaremos y a como estructurar tu proyecto.
#
# Este es un curso práctico, por lo que trabajaremos con las **[Estadísticas de Defunciones Registradas (EDR) de 2020](https://www.inegi.org.mx/programas/edr/)**, una base de datos generada por el Instituto Nacional de Estadística y Geografía (INEGI) de México.

# %% [markdown]
# ## Python y Google Colab
#
# **Python es un lenguaje de programación** interpretado, dinámico y de alto nivel, creado por Guido van Rossum en 1991. Es ampliamente utilizado en diversos campos, incluyendo la ciencia de datos, el desarrollo web, la inteligencia artificial y la automatización de tareas. Python es conocido por ser fácil de aprender y leer, y cuenta con una amplia variedad de bibliotecas y módulos que facilitan el desarrollo de aplicaciones y proyectos. Además, es un lenguaje multiplataforma, lo que significa que se puede utilizar en diferentes sistemas operativos como Windows, Mac y Linux.
#
# Para utilizar Python existen una serie de herramientas, en este curso nos centraremos es **[Google Colab](https://colab.research.google.com/)**. Google Colab es una plataforma gratuita en la nube que permite escribir y ejecutar código Python desde el navegador web. Funciona como un "cuaderno interactivo" o notebook (basado en Jupyter Notebooks) que no requiere instalación previa y ofrece acceso a recursos de hardware avanzados
#
# Un **notebook** es una aplicación web que permite crear y compartir documentos que contienen código, texto, visualizaciones y otros elementos interactivos. Los Notebooks se usan comúnmente en la ciencia de datos y la programación para explorar y analizar datos, desarrollar y probar código y crear informes o presentaciones interactivas.
#
# Los Notebooks están compuestos por **celdas** de dos tipos:
# * **Markdown** permiten escribir texto en [formato Markdown](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax#footnotes). Sirven para documentar el proceso de trabajo.
# * **Code** permiten escribir código en el lenguaje de programación elegido. La salida generada por el código, como texto, tablas, imágenes, etc., también se mostrará en la celda Code.
#
# Para **ejecutar una celda de código**, se puede hacer clic en el botón ▶️ `Run` o presionar `Ctrl + Enter`. Este código es ejecutado por el kernel o motor computacional. En la esquina superior derecha se muestra el estado de ejecución y el lenguaje de programación del kernel.
#
# Ejecuta la siguiente celda y examina las diferentes partes de la celda.

# %%
print( 'Hola mundo!' )
# Out:
# Hola mundo!

# %% [markdown]
# ## Estructura de un proyecto de datos
#
# Todo proyecto de análisis de datos debe estar bien organizado y documentado. Esto garantiza que el trabajo sea repetible, transparente y fácil de entender tanto para ti como para otros. La documentación incluye detallar los pasos, las decisiones tomadas y los resultados obtenidos, lo que es clave para la reproducibilidad.
#
# Además de la organización, es crucial considerar la **ética de los datos**, incluyendo la privacidad, la seguridad y la responsabilidad legal. Es importante tomar medidas para proteger los datos sensibles, por ejemplo, encriptando archivos y restringiendo el acceso.
#
# Un análisis de datos se compone de varias etapas interconectadas. Aunque pueden variar, la mayoría de los proyectos incluyen los siguientes pasos:
# 1.  **Obtención de datos**: Es la fase inicial donde se recopilan los datos. Estos pueden provenir de diversas fuentes, como bases de datos, hojas de cálculo o APIs.
# 2.  **Exploración de datos** (**EDA** por sus siglas en inglés): Aquí te familiarizas con la estructura original del conjunto de datos. Observas su formato, el número de tablas, las columnas que contiene y su contenido.
# 3.  **Limpieza de datos**: En este paso, preparas los datos para el análisis. La limpieza consiste en corregir o eliminar valores incorrectos, duplicados o incompletos para asegurar su calidad.
# 4.  **Análisis**: Una vez que los datos están listos, extraes la información y el conocimiento que buscas. Esta etapa puede incluir múltiples sub-análisis y técnicas.
#
# Además de estos pasos, la **visualización de datos** es una herramienta esencial que se utiliza en casi todas las etapas. Permite representar los datos de forma gráfica, facilitando su comprensión y la identificación de patrones.
#
# Para evitar errores y facilitar la revisión del proceso, es recomendable:
# * **Separar las etapas**: Organiza cada etapa del análisis en diferentes carpetas o archivos.
# * **Documentar las decisiones**: Explica en el notebook las razones detrás del procesamiento de datos, las suposiciones que hiciste o cualquier hipótesis formulada. Esta documentación es crucial para que, a futuro, tanto tú como otros entiendan tu proceso.
# * **Controlar las versiones**: Utiliza sistemas como **Git** para rastrear los cambios en tus archivos y código. Esto te permite tener un historial completo del proyecto.
#
# Es importante recordar que estas etapas no siempre se dan de forma lineal. A menudo, el análisis de datos es un proceso cíclico e iterativo. Después de la limpieza, podrías descubrir nuevos problemas que te obliguen a volver a la etapa de exploración. O, después del análisis, podrías encontrar que necesitas refinar tus datos y volver a la limpieza.
#
# En resumen, un flujo de trabajo organizado y bien documentado es fundamental para que tu análisis sea **confiable**, **reproducible** y de alta calidad.

# %% [markdown]
# ## Entorno de trabajo
#
# Para empezar, organizaremos nuestro proyecto de análisis de datos. Para lograrlo vamos a crear una **carpeta de trabajo** principal dentro de **Google Drive**. Es fundamental que el nombre de esta carpeta sea descriptivo para que, de un vistazo, sepas qué contiene. Por ejemplo, `Python_EDR2020` es un nombre ideal, ya que nos indica que el proyecto usa **Python** para analizar las estadísticas de defunciones (**EDR**) del año **2020**.
#
# Para comenzar, necesitas tener el Notebook y una copia de los datos dentro de tu carpeta de trabajo.
#
# Tienes dos opciones para obtener el Notebook:
#
# 1) **Crear uno nuevo**: Inicia un nuevo Notebook desde la interfaz de [Google Colab](https://colab.research.google.com/).
# 2) **Copiar uno existente**: Si alguien te ha compartido un Notebook, simplemente cópialo en tu carpeta de trabajo. Por ejemplo, puedes copiar [este notebook](https://drive.google.com/file/d/1jHpCfFSxAwFHpT5pqZqHvalOcO_X1IIp/view?usp=sharing).
#
# Una vez que tengas el Notebook creado o copiado **verifica que estés trabajando en la carpeta correcta**.
#
# Una buena práctica es darle al notebook un nombre significativo. Este nombre debe reflejar tanto el proyecto como la etapa en la que te encuentras. Por ejemplo, un nombre como ´EDR1_Colab´ nos indica de inmediato que estamos trabajando en el proyecto de las Estadísticas de Defunciones Registradas (EDR) y que el tema de este notebook es Google Colab. Elegir un buen nombre facilita la organización y el seguimiento de tu trabajo a lo largo del tiempo.

# %% [markdown]
# ## Obtención de datos
#
# A continuación hay que **obtener los datos**, en este caso, trabajaremos con un conjunto de datos real y de importancia para la salud pública: las **Estadísticas de Defunciones Registradas (EDR)**. Este conjunto de datos es producido por el Instituto Nacional de Estadística y Geografía (**INEGI**), la agencia gubernamental encargada de generar la información estadística y geográfica de México. Según el INEGI, el objetivo de las EDR es:
# > "Generar y difundir la información sobre el fenómeno de la mortalidad en el país, lo que permite conocer y comparar el volumen, tendencia y características de la mortalidad en los diferentes ámbitos geográficos de México."
#
# Esta información es crucial para el análisis demográfico, la toma de decisiones en salud pública y la evaluación de programas sociales.
#
# Para nuestro análisis, utilizaremos los **microdatos**. Los microdatos son archivos que contienen la información detallada e individual recopilada en una encuesta o registro, es decir, cada fila corresponde a un registro único (en este caso, una defunción). A diferencia de los datos agregados, que presentan resúmenes, los microdatos nos permiten realizar análisis más profundos y personalizados.
#
# Para obtener el archivo que necesitamos directamente de la fuente oficial:
#
# 1.  **Navega al sitio web del INEGI**: Dirígete a la sección de [datos abiertos del EDR](https://www.inegi.org.mx/programas/edr/#datos_abiertos).
# 2.  **Descarga los datos**: Para este ejercicio, utilizaremos los datos del año **2020**. Busca y descarga el archivo correspondiente. Este archivo es un comprimido (`.zip`) que contiene varias tablas de datos en formato `.csv`.
# 3.  **Descomprime los archivos**: Descomprime el archivo `.zip` en tu computadora lo cual creará una **carpeta de datos** (por ejemplo, `conjunto_de_datos_defunciones_registradas_2020_csv`) que contendrá todos los archivos de datos originales.
# 4.  **Organiza los archivos**: Sube la **carpeta de datos** a la **carpeta de trabajo** en Google Drive que creamos en la sección anterior.
# 5.  **Revisa**: Tu carpeta de trabajo en Google Drive debe contener tanto el notebook como la carpeta de datos del EDR.

# %% [markdown]
# ### Ejercicio
#
# Descarga los archivos del EDR 2020, descomprímelos y colócalos en la **carpeta de trabajo**.

# %% [markdown]
# ## Manejo de Archivos en Google Colab con Google Drive
#
# Google Colab se integra de manera muy eficiente con Google Drive, lo que facilita el acceso y la gestión de tus archivos y conjuntos de datos. Para trabajar con archivos almacenados en tu Drive, primero necesitas **montar** tu Google Drive en el entorno de Colab. Esto crea un enlace temporal entre tu sesión de Colab y tu cuenta de Google Drive.
#
# Cuando ejecutas `drive.mount('/content/drive')`, Colab te pedirá que autorices el acceso a tu Google Drive. Deberás:
#
# 1.  Hacer clic en un enlace que te redirigirá a una página de autenticación de Google.
# 2.  Seleccionar tu cuenta de Google.
# 3.  Otorgar los permisos necesarios a Google Colab.
# 4.  Copiar el código de autorización que se te proporcionará.
# 5.  Pegar este código en el campo que aparecerá en la celda de Colab y presionar Enter.
#
# Una vez autenticado, verás el mensaje `Mounted at /content/drive`, indicando que tu Drive ha sido montado exitosamente.

# %%
# Importar la biblioteca 'drive' de google.colab
from google.colab import drive

# Montar Google Drive
# Una vez montado, tus archivos de Google Drive serán accesibles en el directorio /content/drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Sistemas de Carpetas
#
# En un sistema de archivos, las carpetas (o directorios) se organizan de forma jerárquica, como un árbol. La raíz de este árbol es el directorio principal. En este curso trabajaremos con **rutas absolutas**, es decir, la dirección completa de un archivo o carpeta desde la raíz del sistema (por ejemplo, `/content/drive/MyDrive/Trabajo/Python_EDR2020/mi_archivo.csv`).
#
# Para leer archivos, siempre especificarás la ruta correcta desde donde se está ejecutando tu código.
#
# Una vez montado, tu Google Drive estará disponible en la ruta `/content/drive`. Dentro de este directorio, encontrarás la estructura de carpetas de tu Drive, incluyendo la carpeta `MyDrive`, que es la raíz de tu unidad.
#
# Para verificar que los archivos de tu carpeta de trabajo (`Python_EDR2020` en este ejemplo) son accesibles y para entender la estructura de directorios, puedes usar el comando de términal `ls` directamente en las celdas de Colab, precediéndolos con un `!`.
# *   `!ls`: Lista el contenido del directorio actual.
# *   `!ls /ruta/a/carpeta`: Lista el contenido de una carpeta específica.

# %%
# Listar el contenido de la carpeta específica para tu proyecto, por ejemplo 'Python_EDR2020'
# Es necesario que cambies este path dependiendo del orden de tus archivos
# !ls /content/drive/MyDrive/Trabajo/Python_EDR2020
# Out:
# conjunto_de_datos_defunciones_registradas_2020_csv  EDR4_Limpieza.ipynb
# defunciones_covid19_2020.csv			    EDR5_Remodelacion.ipynb
# defunciones_covid19_2020.parquet		    EDR6_Visualizacion.ipynb
# defunciones_covid19_extra_2020.parquet		    EDR7_Perfiladores.ipynb
# EDR1_Colab.ipynb				    outputs
# EDR2_IntroPython.ipynb				    reference
# EDR3_Seleccion.ipynb

# %% [markdown]
# ## Bibliotecas de Python
#
# En Python, una **biblioteca** (también conocida como `paquete` o `módulo`) es una colección de funciones, clases y métodos prehechos que puedes usar en tu código. Estas bibliotecas extienden las capacidades de Python, permitiéndote realizar tareas complejas sin tener que escribir todo el código desde cero.
#
# Las bibliotecas son fundamentales en el análisis de datos, ya que proporcionan herramientas optimizadas para manipular, analizar y visualizar grandes volúmenes de información. Al utilizar bibliotecas, los científicos de datos pueden ahorrar tiempo, reducir errores y centrarse en la lógica del análisis en lugar de en la implementación de algoritmos básicos.
#
# Algunas de las bibliotecas más importantes para el análisis de datos en Python incluyen:
#
# *   **`pandas`**: Para manipulación y análisis de datos tabulares (DataFrames).
# *   **`NumPy`**: Para computación numérica y operaciones con arrays multidimensionales.
# *   **`Matplotlib`** y **`Seaborn`**: Para visualización de datos.
#
# Para usar una biblioteca en tu código, primero debes **importarla**. La sintaxis común es `import nombre_de_la_biblioteca` o `import nombre_de_la_biblioteca as alias` para usar un nombre más corto (como `import pandas as pd`).
#
# Generalmente Google Colab ya tiene muchas de estas bibliotecas instaladas automáticamente. Si una biblioteca no está instalada en tu entorno, puedes instalarla usando el comando `!pip install nombre_de_la_biblioteca` en una celda de Colab.
#
# Los datos del EDR son una serie de tablas en formato `.csv`. Para trabajar con nuestros datos, usaremos la biblioteca `pandas`, que es la herramienta estándar de Python para el análisis y manipulación de datos tabulares. Para usarla, primero debemos **importar las bibliotecas**. Es una convención muy común en la comunidad de Python importarla con el alias `pd`, lo que nos permite referirnos a ella de forma más corta y práctica.

# %%
! pip install pandas

import pandas as pd

# %% [markdown]
# ## Apertura del conjunto de datos en el Notebook
#
# Cargar un conjunto de datos implica mucho más que simplemente abrir un archivo. Es el proceso de transferir datos almacenados en un formato externo (como un archivo CSV, una base de datos o un archivo de texto) a la memoria de trabajo de tu programa. Es el puente entre los datos "en reposo" y los datos "en acción".
#
# Primero, es necesario conocer la ruta o `path` de nuestro conjunto de interés. Una forma de hacer esto:
# 1. Oprimir el icono de carpeta en la parte izquierda de la pantalla. Esto desplegará los archivos en nuestro Google Drive
# 2. Navegar hasta encontrar el archivo que queremos hacer. En este caso se sigue la ruta `drive` -> `MyDrive` -> `Trabajo` -> `Python_EDR2020` -> `conjunto_de_datos_defunciones_registradas_2020_csv` -> `conjunto_de_datos` -> `conjunto_de_datos_defunciones_registrados_2020.csv`. Sin embargo, **esta ruta cambia** según donde ubiques tus archivos.
# 3. Oprime los tres puntos al lado del archivo que te interesa y selecciona `Copy path` para copiar la ruta.
# 4. Pega la ruta en la variable `file_name`. Asegúrate que esté entre comillas.
#
# A partir de esto abriremos el archivo usando la función `pd.read_csv(file_name)`. Revisamos que el proceso funciono escribiendo `df` **en la última línea de la celda**. Esto nos muestra la tabla en la celda de output, pero ya que esta es muy grande, solo nos muestra las primeras y últimas filas, representando las faltantes con `...`. En la esquina inferior izquierda se puede ver el número de filas y columnas.
#
# En las siguientes secciones veremos estos comandos con más detenimiento.
#
# > Nota: La versión gratuita de Google Colab tiene recursos limitados, por lo tanto cargaremos el archivo con tipo de datos `str` y usaremos solo las primeras 10000 filas.

# %%
file_name = '/content/drive/MyDrive/Trabajo/Python_EDR2020/conjunto_de_datos_defunciones_registradas_2020_csv/conjunto_de_datos/conjunto_de_datos_defunciones_registrados_2020.csv'
df = pd.read_csv(file_name, nrows=10000)
df
# Out:
#       ent_regis  mun_regis  ent_resid  mun_resid  tloc_resid  loc_resid  \
# 0             1          1          1          1          15          1
# 1             1          1          1          1          15          1
# 2             1          1          1          1          15          1
# 3             1          1          1          1          15          1
# 4             1          6          1          9           4          1
# ...         ...        ...        ...        ...         ...        ...
# 9995          2          2          2          2           3        211
# 9996          2          2          2          2           4        227
# 9997          2          2          2          2           1       2135
# 9998          2          1          2          1          14          1
# 9999          2          1          2          1          14          1
#
#       ent_ocurr  mun_ocurr  tloc_ocurr  loc_ocurr  ... anio_cert maternas  \
# ...

# %% [markdown]
# ## Ejercicio
#
# 1. Crea una **carpeta de trabajo** para este curso en tu Google Drive. Este debé contener:
#     * Copia de este notebook
#     * Carpeta de datos del EDR 2020 descomprimida
# 2. Abre el notebook que se encuentra en tu **carpeta de trabajo** y ejecuta todas las celdas
#     * Antes de empezar oprime la flecha que se encuentra al lado de `Run all` y oprime `Clear all outputs`. Esto borra todos las salidas del notebook.
#     * Recuerda modificar las rutas o paths de acuerdo a la estructura de archivos en tu Google Drive
# 3. En un documento de texto incluye capturas de pantalla de:
#     * La **carpeta de trabajo** con el notebook y carpeta de datos
#     * La celda de salida donde se despliega el conjunto de datos (`df`)

# %% [markdown]
# ## Resumen
#
# En esta lección hemos aprendido varios conceptos:
# * Python y Google Colab como entorno de programación
# * Notebooks y sus principales tipos de celdas:
#     * Markdown: para escribir texto
#     * Code: para programar
# * Estructura de un proyecto de datos: obtención, exploración, limpieza, análisis
# * Organización de los archivos de un proyecto de datos
# * Manejo de archivos en Google Drive
# * Sistemas de carpetas y rutas o paths
# * Cargar datos a pandas
#
# **¡Gracias!**
